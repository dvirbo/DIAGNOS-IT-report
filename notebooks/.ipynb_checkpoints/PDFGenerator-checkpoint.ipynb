# %%
# !pip install FPDF

# %%
from fpdf import FPDF

# %%
# page 1 params:
title = "Example of title"
year = "2022"
month = "Juin 5"
child_name = "name 1"
authored = "name 2"
logo_path = 'logo.PNG'
logo_name = "FreeuuuLance"

# page 2 params:
title_heading = "Title Heading"
sub_title = "Sub Title Text"
paragraph_1 = "To calculate the length of a string in Python, you can use the built-in len() method. It takes a string as a parameter and returns an integer as the length of that string. "
paragraph_2 = paragraph_3 = paragraph_4 = paragraph_1

# pdf destination
pdf_dest = 'Report.pdf'

# %%
def pdf_generator(title, year, month, child_name, authored, logo_path, logo_name, title_heading, sub_title, paragraph_1, paragraph_2, paragraph_3, paragraph_4):
   
    pdf = FPDF(orientation="P", unit="mm", format="A4")
    pdf.add_page()

    # ======================= first page ==============================
    

    pdf.set_font("arial", "B", 28.0)
    pdf.image('image.jpg', x = 0, y = 0, w = 210, h = 297)
    # 1- add pdf title
    pdf.set_text_color(0, 0, 150)
    pdf.set_xy(20, 35)
    #title = "Example of title"
    pdf.cell(20, 10, txt=title, ln=1, align='L') 

    # add year + line
    pdf.set_xy(20, 55)
    #year = "2022"
    pdf.cell(20, 10, txt=year, ln=1, align='L') 
    pdf.line(21, 65, 50, 65)

    # add month + line
    pdf.set_font("arial", "", 13.0)
    pdf.set_text_color(0, 0, 150)
    pdf.set_xy(20, 230)
    #month = "Juin 5"
    pdf.cell(20, 10, txt=month, ln=1, align='L') 
    pdf.line(21, 240, 50, 240)

    # add child name + authored by
    pdf.set_font("arial", "B", 10.0)
    pdf.set_text_color(0, 0, 150)
    pdf.set_xy(20, 243)
    #child_name = "name 1"
    pdf.cell(20, 10, txt="Child Name: "+child_name, ln=1, align='L') 
    pdf.set_xy(20, 248)
    #authored = "name 2"
    pdf.cell(20, 10, txt="Authored by: "+authored, ln=1, align='L')


    # add logo + logo name
    #logo_path = 'logo.PNG'
    pdf.image(logo_path, x = 150, y = 250, w = 20, h = 20)

    pdf.set_font("arial", "B", 13.0)
    pdf.set_text_color(255,255,255)
    pdf.set_xy(172, 251)
    #logo_name = "FreeuuuLance"
    if ' ' in logo_name and len(logo_name)>6:
        str_list = logo_name.rsplit(' ',2)
        pdf.cell(20, 10, txt=str_list[0], ln=1, align='L')
        pdf.set_xy(172, 256)
        pdf.cell(20, 10, txt=str_list[1], ln=1, align='L')
    else:
        pdf.multi_cell(20, 5, txt=logo_name, align='L')


    # ======================= second page ==============================
    pdf.add_page()
    pdf.line(21, 20, 180, 20)

    # heading title
    pdf.set_font("arial", "B", 22.0)
    pdf.set_text_color(0, 0, 0)
    pdf.set_xy(20, 25)
    #title_heading = "Title Heading"
    pdf.cell(20, 10, txt=title_heading, ln=1, align='L') 

    # sub title
    pdf.set_font("arial", "", 14.0)
    pdf.set_text_color(0, 0, 150)
    pdf.set_xy(21, 35)
    #sub_title = "Sub Title Text"
    pdf.cell(20, 10, txt=sub_title, ln=1, align='L') 

    # paragraph_1
    pdf.set_font("arial", "", 10.0)
    pdf.set_text_color(0, 0, 130)
    pdf.set_xy(21, 55)
    #paragraph_1 = "To calculate the length of a string in Python, you can use the built-in len() method. It takes a string as a parameter and returns an integer as the length of that string. "
    pdf.multi_cell(180, 7, txt=paragraph_1, align='L') 

    # paragraph_2
    pdf.set_xy(21, 75)
    #paragraph_2 = "To calculate the length of a string in Python, you can use the built-in len() method. It takes a string as a parameter and returns an integer as the length of that string. "
    pdf.multi_cell(180, 7, txt=paragraph_2, align='L') 

    # add some image
    pdf.image('text-custom-font.png', x = 52, y = 95, w = 100, h = 20)


    # paragraph_3
    pdf.set_xy(21, 130)
    #paragraph_3 = "To calculate the length of a string in Python, you can use the built-in len() method. It takes a string as a parameter and returns an integer as the length of that string. "
    pdf.multi_cell(180, 7, txt=paragraph_3, align='L')


    # paragraph_4
    pdf.set_xy(21, 150)
    #paragraph_4 = "To calculate the length of a string in Python, you can use the built-in len() method. It takes a string as a parameter and returns an integer as the length of that string. "
    pdf.multi_cell(180, 7, txt=paragraph_4, align='L')


    # add plots
    pdf.image('race_dist.png', x = 30, y = 180, w = 75, h = 65)

    pdf.image('race_dist.png', x = 110, y = 180, w = 75, h = 65)


    # add page number
    pdf.set_font("arial", "B", 10.0)
    pdf.set_text_color(0, 0, 130)
    pdf.set_xy(100, 265)
    pdf.multi_cell(180, 7, txt="2", align='L')




    # ======================= third page ==============================
    pdf.add_page()
    pdf.line(21, 20, 180, 20)
    pdf.set_font("arial", "B", 10.0)
    # 1- add pdf title
    pdf.set_text_color(0, 0, 130)
    pdf.set_xy(100, 265)
    pdf.multi_cell(180, 7, txt="3", align='L')
    pdf.add_font('DejaVu', '', 'DejaVuSansCondensed.ttf', uni=True)
    pdf.set_font('DejaVu', '', 14)
    
    text = u"""
    English: Hello World
    Greek: Γειά σου κόσμος
    Polish: Witaj świecie
    Portuguese: Olá mundo
    Russian: Здравствуй, Мир
    Vietnamese: Xin chào thế giới
    Arabic: مرحبا العالم
    Hebrew: שלום עולם
    """

    #paragraph_3 = "To calculate the length of a string in Python, you can use the built-in len() method. It takes a string as a parameter and returns an integer as the length of that string. "
    pdf.multi_cell(180, 7, txt=text, align='L')
    # Note :
    # you can add more page just add pdf.add_page()
    # if there is problem with text position try to ajust x and y position
    
    pdf.output(pdf_dest)

# %%
pdf_generator(title, year, month, child_name, authored, logo_path, logo_name, title_heading, sub_title, paragraph_1, paragraph_2, paragraph_3, paragraph_4)
